# %% [markdown]
# # 🚗 Análisis Exploratorio de Datos de Vehículos
#
# En este notebook realizaremos un análisis exploratorio básico de un conjunto de datos de anuncios de venta de coches.
# El objetivo es limpiar los datos, revisar estadísticas descriptivas y crear visualizaciones interactivas usando Plotly.

# %%
# 📦 Librerías necesarias
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## 📂 Carga del dataset
#
# Leemos el archivo CSV con los datos de vehículos.
# Asegúrate de que el archivo `vehicles_us.csv` esté en la ruta correcta.

# %%
df = pd.read_csv('../vehicles_us.csv')

df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %% [markdown]
# # 🔍 Información general y estadísticas descriptivas
#
# - `info()`: muestra tipos de datos y número de valores no nulos.
# - `describe()`: muestra estadísticas básicas (mínimo, máximo, media, percentiles).

# %%
print("Información general del dataset:")
print(df.info())

print("\nEstadísticas descriptivas:")
print(df.describe(include='all'))
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
# None
#
# Estadísticas descriptivas:
#                 price    model_year       model  condition     cylinders  \
# ...

# %% [markdown]
# ## 🧹 Limpieza de datos
#
# En esta sección manejamos los valores nulos:
#
# - Columnas numéricas: rellenamos con la **mediana**.
# - Columnas categóricas: rellenamos con **"Desconocido"**.
#
# Esto nos asegura que los gráficos y análisis posteriores funcionen correctamente.

# %%
df.isnull().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
# Columnas numéricas
num_cols = df.select_dtypes(include='number').columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# Columnas categóricas
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    df[col] = df[col].fillna('Desconocido')

# Verificación de datos nulos
df.isnull().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %% [markdown]
# ## 📊 Visualizaciones
#
# A continuación, creamos gráficos interactivos para explorar las distribuciones y relaciones en los datos.

# %% [markdown]
# ### Histograma de Precios
#
# Visualizamos la distribución de precios de los vehículos.
# Esto ayuda a identificar rangos más comunes y posibles valores atípicos.

# %%
fig_price = px.histogram(df, x='price', nbins=50, title='Distribución de Precios')
fig_price.show()

# %% [markdown]
# ### Histograma de Odómetro
#
# Muestra la distribución de los valores de kilometraje (odometer) de los vehículos.
# Se utiliza `plotly.graph_objects` como ejemplo alternativo.

# %%
fig_odometer = go.Figure(data=[go.Histogram(x=df['odometer'])])
fig_odometer.update_layout(title_text='Distribución del Odómetro')
fig_odometer.show()

# %% [markdown]
# ### Scatter Plot: Precio vs Año
#
# Visualizamos la relación entre el **año del modelo** y el **precio**, coloreado por modelo.
# Esto permite detectar tendencias y valores atípicos según la marca o tipo de vehículo.

# %%
fig_scatter = px.scatter(df, x='model_year', y='price', color='model',
                         title='Precio vs Año por Marca', opacity=0.7)
fig_scatter.show()

# %% [markdown]
# # ✅ Conclusiones preliminares
#
# - Se detectaron y limpiaron valores nulos para asegurar integridad de los datos.
# - La distribución de precios muestra un rango amplio, con algunos valores atípicos.
# - La relación entre año del vehículo y precio indica que, en general, los autos más nuevos tienden a tener precios más altos.
# - Estos gráficos servirán como base para construir el **dashboard interactivo en Streamlit**.
